# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
import pandas as pd
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager
from geopy.geocoders import Nominatim

# %%
import requests
import json
from dotenv import load_dotenv
import os
import pandas as pd
from functools import reduce
import operator
from pymongo import MongoClient
from pymongo import GEOSPHERE
import sys
from bson.json_util import dumps
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster

# %%
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)

opciones.headless=False    # si True, no aperece la ventana (headless=no visible)

opciones.add_argument('--start-maximized')         # comienza maximizado

opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies

#opciones.add_extension('driver_folder/adblock.crx')       # adblocker

opciones.add_argument('--incognito')              # incognito

# %%
# sacar urls ESTO VALEEEEE
dic_url = {"URL": []}
lista_mid_urls = []



driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
try: 
    url = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=3"
    driver.get(url)
    driver.implicitly_wait(2)
    driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
    driver.implicitly_wait(10)

    for i in range(1,31):

        try:
            dic_url["URL"].append(driver.find_element_by_css_selector(f"#BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child({i}) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title").get_attribute("onclick"))
            print("We have the restaurant's URL 🚀", i)

            urls = list(dic_url.values())
        except: 
            pass

    driver.quit()
except: 
    pass
            

        
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

    # Paginas
#1  https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=3
#2  https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=4&o=30
#3  https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=5&o=60
#4  https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=6&o=90
#5  https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=7&o=120
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/96.0.4664.45/chromedriver_mac64.zip
# Driver has been saved in cache [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45]
# <ipython-input-4-fea576b78d09>:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-4-fea576b78d09>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-4-fea576b78d09>:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
lista_mid_urls
# Out:
# ['/Restaurant_Review-g187514-d9879706-Reviews-La_Bistroteca-Madrid.html',
#  '/Restaurant_Review-g187514-d2006562-Reviews-Los_Montes_de_Galicia-Madrid.html',
#  '/Restaurant_Review-g187514-d6776681-Reviews-Platea_Madrid-Madrid.html',
#  '/Restaurant_Review-g187514-d12431974-Reviews-Chow_Chow_Madrid-Madrid.html',
#  '/Restaurant_Review-g187514-d8018926-Reviews-TATEL_Madrid-Madrid.html',
#  '/Restaurant_Review-g187514-d1027419-Reviews-Chocolateria_San_Gines-Madrid.html',
#  '/Restaurant_Review-g187514-d8860328-Reviews-Kuche_Madrid-Madrid.html',
#  '/Restaurant_Review-g187514-d795430-Reviews-Rubaiyat_Madrid-Madrid.html',
#  '/Restaurant_Review-g187514-d2001274-Reviews-Enigmatium_Madrid-Madrid.html',
#  '/Restaurant_Review-g187514-d1810038-Reviews-Ramon_Freixa_Madrid-Madrid.html',
#  '/Restaurant_Review-g187514-d12276388-Reviews-Maddock_Madrid-Madrid.html',
#  '/Restaurant_Review-g187514-d988131-Reviews-Viejo_Madrid-Madrid.html',
# ...

# %%
#mercado de san miguel(segunda pagina)
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (4,35), range (0,100,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-6-8c95fe6e0ba7>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-6-8c95fe6e0ba7>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-6-8c95fe6e0ba7>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=87&o=60
https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=90&o=90
https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=89&o=120
# Out:
#   File "<ipython-input-7-7e78085aa432>", line 1
#     https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=87&o=60
#           ^
# SyntaxError: invalid syntax

# %%
lista_mid_urls

# %%
#cannibal(quinta pagina)
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (5,35), range (90,150,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()

# %%
lista_mid_urls

# %%
driver.quit()

# %%
#cebo(cuarta pagina)

driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (6,35), range (60,150,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()

# %%
#de maria gran via (tercera pagina)
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (7,35), range (150,300,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()

# %%
# Goiko- Maria de Molina 20 (tercera pagina)
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (10,35), range (210,500,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()

# %%
# Gandario
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (25,35), range (270,500,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()

# %%
# las noches de moscu (pagina 13)
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (27,35), range (330,500,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()

# %%
# poncelet (pagina 14)
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (28,35), range (360,500,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()

# %%
# bar museo chicote (pagina 15) 
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (34,35), range (390,500,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()

# %%
# quispe (pagina ?) 
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (34,35), range (410,600,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()

# %%
# la negra tomasa (pagina 17) 
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (39,40), range (450,600,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()

# %%
# meson molinero (pagina 19) 
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (41,60), range (510,650,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-61-d46a7af05538>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-61-d46a7af05538>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-61-d46a7af05538>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
# antonella (pagina 20) 
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (43,60), range (540,650,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-63-b7c054b414a9>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-63-b7c054b414a9>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-63-b7c054b414a9>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
# casa macareno(pagina 21) 
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (44,60), range (570,650,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-64-930fc32f889a>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-64-930fc32f889a>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-64-930fc32f889a>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
# el columpio (pagina 22) 
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (45,60), range (600,700,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-66-bbd521334599>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-66-bbd521334599>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-66-bbd521334599>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
# Piscomar(pagina 23) 
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (46,60), range (630,700,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-69-da454e7017fd>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-69-da454e7017fd>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-69-da454e7017fd>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
print(lista_mid_urls)
# Out:
# ['/Restaurant_Review-g187514-d9879706-Reviews-La_Bistroteca-Madrid.html', '/Restaurant_Review-g187514-d2006562-Reviews-Los_Montes_de_Galicia-Madrid.html', '/Restaurant_Review-g187514-d6776681-Reviews-Platea_Madrid-Madrid.html', '/Restaurant_Review-g187514-d12431974-Reviews-Chow_Chow_Madrid-Madrid.html', '/Restaurant_Review-g187514-d8018926-Reviews-TATEL_Madrid-Madrid.html', '/Restaurant_Review-g187514-d1027419-Reviews-Chocolateria_San_Gines-Madrid.html', '/Restaurant_Review-g187514-d8860328-Reviews-Kuche_Madrid-Madrid.html', '/Restaurant_Review-g187514-d795430-Reviews-Rubaiyat_Madrid-Madrid.html', '/Restaurant_Review-g187514-d2001274-Reviews-Enigmatium_Madrid-Madrid.html', '/Restaurant_Review-g187514-d1810038-Reviews-Ramon_Freixa_Madrid-Madrid.html', '/Restaurant_Review-g187514-d12276388-Reviews-Maddock_Madrid-Madrid.html', '/Restaurant_Review-g187514-d988131-Reviews-Viejo_Madrid-Madrid.html', '/Restaurant_Review-g187514-d10159455-Reviews-Angelita_Madrid-Madrid.html', '/Restaurant_Re
# ...

# %%
# La mancha en madrid(pagina 24) 
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (47,60), range (660,700,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-70-046f60152500>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-70-046f60152500>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-70-046f60152500>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
# cafe de la luz(pagina 25) 
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (48,60), range (690,800,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-79-731d6722cc05>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-79-731d6722cc05>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-79-731d6722cc05>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
# Meson Gregorio III(pagina 26) 
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (49,60), range (720,900,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-80-72614fc2ad68>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-80-72614fc2ad68>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-80-72614fc2ad68>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
# LA RAMONA (pagina 29) 
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (48,70), range (810,900,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-82-c5225ff785b6>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-82-c5225ff785b6>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-82-c5225ff785b6>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
# KM DE PIZZA(pagina 28) 
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (51,70), range (780,900,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-84-8ef14c683ed1>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-84-8ef14c683ed1>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-84-8ef14c683ed1>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
# cerverceria santa barbara(pagina 30) 
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (53,70), range (840,1000,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-86-4008e4815374>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-86-4008e4815374>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-86-4008e4815374>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
# las bravas?
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (54,70), range (870,1000,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-87-5b2bd2d85e90>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-87-5b2bd2d85e90>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-87-5b2bd2d85e90>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
#lAS BRAVAS, PAGINA 31
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (55,70), range (900,1000,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-88-97b9aa44632d>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-88-97b9aa44632d>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-88-97b9aa44632d>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
#trattoria la tavernetta, (32)
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (56,70), range (930,1000,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-89-b0a9bab224a7>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-89-b0a9bab224a7>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-89-b0a9bab224a7>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
# los espetinhos, pagina 33

driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (57,70), range (960,1000,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()

# %%
# 
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i, t in zip(range (58,70), range (990,1500,30)[1:]):
       
    try:
        url2 = f"https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf={i}&o={t}"
        driver.get(url2)
        driver.implicitly_wait(2)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        driver.implicitly_wait(10)

        for z in (range(1,31)):
            try:
                dic_url["URL"].append(driver.find_element_by_xpath(f"/html/body/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[{z}]/div/div/div/div[2]/div[1]/div[2]").get_attribute("onclick"))
                print("We have the restaurant's URL 🚀", i)

                urls = list(dic_url.values())
                
            except: 
                pass

    except: 
        pass

    
for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-90-c9971f0fb698>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-90-c9971f0fb698>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-90-c9971f0fb698>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
#driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
final_list = []

for i in lista_mid_urls:
    final_list.append("https://www.tripadvisor.es" + i)

# %%
final_list
# Out:
# ['https://www.tripadvisor.es/Restaurant_Review-g187514-d9879706-Reviews-La_Bistroteca-Madrid.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g187514-d2006562-Reviews-Los_Montes_de_Galicia-Madrid.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g187514-d6776681-Reviews-Platea_Madrid-Madrid.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g187514-d12431974-Reviews-Chow_Chow_Madrid-Madrid.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g187514-d8018926-Reviews-TATEL_Madrid-Madrid.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g187514-d1027419-Reviews-Chocolateria_San_Gines-Madrid.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g187514-d8860328-Reviews-Kuche_Madrid-Madrid.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g187514-d795430-Reviews-Rubaiyat_Madrid-Madrid.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g187514-d2001274-Reviews-Enigmatium_Madrid-Madrid.html',
# ...

# %%
len(final_list)
# Out:
# 24435

# %%
resultant_list = []
 
for element in final_list:
    if element not in resultant_list:
        resultant_list.append(element)

print(resultant_list)
# Out:
# ['https://www.tripadvisor.es/Restaurant_Review-g187514-d9879706-Reviews-La_Bistroteca-Madrid.html', 'https://www.tripadvisor.es/Restaurant_Review-g187514-d2006562-Reviews-Los_Montes_de_Galicia-Madrid.html', 'https://www.tripadvisor.es/Restaurant_Review-g187514-d6776681-Reviews-Platea_Madrid-Madrid.html', 'https://www.tripadvisor.es/Restaurant_Review-g187514-d12431974-Reviews-Chow_Chow_Madrid-Madrid.html', 'https://www.tripadvisor.es/Restaurant_Review-g187514-d8018926-Reviews-TATEL_Madrid-Madrid.html', 'https://www.tripadvisor.es/Restaurant_Review-g187514-d1027419-Reviews-Chocolateria_San_Gines-Madrid.html', 'https://www.tripadvisor.es/Restaurant_Review-g187514-d8860328-Reviews-Kuche_Madrid-Madrid.html', 'https://www.tripadvisor.es/Restaurant_Review-g187514-d795430-Reviews-Rubaiyat_Madrid-Madrid.html', 'https://www.tripadvisor.es/Restaurant_Review-g187514-d2001274-Reviews-Enigmatium_Madrid-Madrid.html', 'https://www.tripadvisor.es/Restaurant_Review-g187514-d1810038-Reviews-Ramon_Freix
# ...

# %%
len(resultant_list)
# Out:
# 730

# %%
# el bueno
dic2 = {"name":[], "address":[], "type":[],"ranking":[],"price":[]}
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i in resultant_list[700:730]:

    try:
        driver.get(i)
        time.sleep(5)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        dic2["name"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[1]/h1").text)
        print("We have the restaurant's name🍴")
        #aqui cojo el texto del nombre)
        dic2["address"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[3]/span[1]/span/a").text)
        print("We know were it is 📍")
        #aqui cojo el texto de la dirección
        dic2["type"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[2]/span[3]/a[2]").text)
        print("We know the type of food it can offer 🍕🍱🥘")
        #aqui cojo el texto de la dirección
        dic2["ranking"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[2]/span[2]/a/span").text)
        print("We know how good it is 📈")
        #aqui cojo el texto de la dirección
        dic2["price"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[2]/span[3]/a[1]").text)
        print("How pricy is it? 💸")
        
        

        
    except: 
        driver.get(i)
        time.sleep(5)
        dic2["name"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[1]/h1").text)
        print("We have the restaurant's name🍴")
        #aqui cojo el texto del nombre)
        dic2["address"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[3]/span[1]/span/a").text)
        print("We know were it is 📍")
        #aqui cojo el texto de la dirección
        dic2["type"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[2]/span[3]/a[2]").text)
        print("We know the type of food it can offer 🍕🍱🥘")
        #aqui cojo el texto de la dirección
        dic2["ranking"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[2]/span[2]/a/span").text)
        print("We know how good it is 📈")
        #aqui cojo el texto de la dirección
        dic2["price"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[2]/span[3]/a[1]").text)
        print("How pricy is it? 💸")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-218-2aa2ed2a3976>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-218-2aa2ed2a3976>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-218-2aa2ed2a3976>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dic2["name"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[1]/h1").text)
# We have the restaurant's name🍴
# We know were it is 📍
# ...

# %%
len(dic2)
# Out:
# 5

# %%
len(dic2["name"])
# Out:
# 30

# %%
dic2
# Out:
# {'name': ['Taberna del Quinto Vino',
#   'Dogma',
#   'La Nicoletta Castellana',
#   'Bodegas Casas',
#   'Bico de Xeado',
#   'Taberna O Curruncho',
#   'Diaz y Larrouy',
#   'QUIMBAYA by Edwin Rodríguez',
#   "Fratelli d'italia Lavapiés",
#   'Tequeños Que Molan',
#   'La Cruzada',
#   'Makkila Fernando VI',
#   'Mikado',
#   'La Penela Restaurante Gallego. Velázquez',
#   'La Mafia se sienta a la mesa',
#   'La Copita Asturiana',
#   'Plaza Mayor',
#   'Restaurante Konnichiwa',
#   'Green Tea Sushi & Cocktail - Hotel the Westin Palace',
#   'Il Cratere del Gusto',
#   'Viandas de Salamanca',
#   'Sensaciones',
#   'Regañadientes',
#   'Llantén Veggie Bar',
#   'Panem Panaderia Artesana,s.l.',
#   'Ganz Wine Bar',
#   'Cafelito',
#   'Panela & Co',
#   'Sua By Triciclo In Madrid',
#   'La Máquina Original'],
#  'address': ['Calle Hernani 48, 28020 Madrid España',
#   'Avenida de Alberto Alcocer 43, 28016 Madrid España',
#   'Paseo de la Castellana 4, 28001 Madrid España',
# ...

# %%
df = pd.DataFrame.from_dict(dic2, orient='index')

# %%
df
# Out:
#                                               0   \
# name                     Taberna del Quinto Vino
# address    Calle Hernani 48, 28020 Madrid España
# type                                Mediterránea
# ranking  #2.375 de 10.409 restaurantes en Madrid
# price                                   €€ - €€€
#
#                                                         1   \
# name                                                 Dogma
# address  Avenida de Alberto Alcocer 43, 28016 Madrid Es...
# type                                  Restaurante de carne
# ranking              #187 de 10.409 restaurantes en Madrid
# price                                                 €€€€
#
#                                                     2   \
# name                           La Nicoletta Castellana
# address  Paseo de la Castellana 4, 28001 Madrid España
# type                                          Italiana
# ranking        #4.004 de 10.409 restaurantes en Madrid
# ...

# %%
df = df.transpose()

# %%
df
# Out:
#                                                  name  \
# 0                             Taberna del Quinto Vino
# 1                                               Dogma
# 2                             La Nicoletta Castellana
# 3                                       Bodegas Casas
# 4                                       Bico de Xeado
# 5                                 Taberna O Curruncho
# 6                                      Diaz y Larrouy
# 7                         QUIMBAYA by Edwin Rodríguez
# 8                          Fratelli d'italia Lavapiés
# 9                                  Tequeños Que Molan
# 10                                         La Cruzada
# 11                                Makkila Fernando VI
# 12                                             Mikado
# 13           La Penela Restaurante Gallego. Velázquez
# 14                       La Mafia se sienta a la mesa
# 15                                La Copita Asturiana
# ...

# %%
df.shape
# Out:
# (30, 5)

# %%
df.to_csv("700-730.csv")

# %%
#Import csv
df_0 = pd.read_csv('100primeros.csv')
df_1 = pd.read_csv('100-137.csv')
df_2 = pd.read_csv('200-300.csv')
df_3 = pd.read_csv('300-400.csv')
df_4 = pd.read_csv('500-600.csv')
df_5 = pd.read_csv('600-700.csv')
df_6 = pd.read_csv('700-730.csv')

# %%
df_0.shape
# Out:
# (137, 6)

# %%
df_1.shape  #100-137
# Out:
# (37, 6)

# %%
df_2.shape  #200-300
# Out:
# (51, 6)

# %%
df_3.shape #300-400
# Out:
# (83, 6)

# %%
df_4.shape #500-600
# Out:
# (100, 6)

# %%
df_5.shape #600-700
# Out:
# (100, 6)

# %%
df_6.shape #700-730
# Out:
# (30, 6)

# %%
df_total_1 = pd.concat([df_0, df_2, df_3, df_4, df_5, df_6])
df_total_1
# Out:
#     Unnamed: 0                       name  \
# 0            0              La Bistroteca
# 1            1      Los Montes de Galicia
# 2            2              Platea Madrid
# 3            3           Chow Chow Madrid
# 4            4               TATEL Madrid
# ..         ...                        ...
# 25          25              Ganz Wine Bar
# 26          26                   Cafelito
# 27          27                Panela & Co
# 28          28  Sua By Triciclo In Madrid
# 29          29        La Máquina Original
#
#                                               address                  type  \
# 0   Calle Espartinas 7, local izquierda Barrio Sal...                Fusión
# 1                Calle Azcona 46, 28028 Madrid España         Internacional
# 2      C/ Goya, 5-7 C/ Goya, 5-7, 28001 Madrid España              Italiana
# 3    Avenida de Concha Espina 55, 28016 Madrid España              Japonesa
# ...

# %%
df_total_1.to_csv('df_total_1.csv')

# %%
df_total_1 = pd.read_csv('df_total_1.csv')

# %%
df_total_1.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                   name  \
# 0           0             0          La Bistroteca
# 1           1             1  Los Montes de Galicia
# 2           2             2          Platea Madrid
# 3           3             3       Chow Chow Madrid
# 4           4             4           TATEL Madrid
#
#                                              address           type  \
# 0  Calle Espartinas 7, local izquierda Barrio Sal...         Fusión
# 1               Calle Azcona 46, 28028 Madrid España  Internacional
# 2     C/ Goya, 5-7 C/ Goya, 5-7, 28001 Madrid España       Italiana
# 3   Avenida de Concha Espina 55, 28016 Madrid España       Japonesa
# 4    Paseo de la Castellana, 36, 28046 Madrid España  Internacional
#
#                                    ranking     price
# 0     #14 de 10.414 restaurantes en Madrid  €€ - €€€
# 1      #1 de 10.414 restaurantes en Madrid  €€ - €€€
# 2    #654 de 10.414 restaurantes en Madrid  €€ - €€€
# ...

# %%
#df_total.address.unique

# %%
import re

# %%
def comunidad(x):
    return (re.split('\d{5}', x)[0])

# %%
def direccion(x):
    return (re.split('\d{5}', x)[-1])

# %%
df_total_1["direccion"] = df_total_1.address.apply(comunidad)

# %%
df_total_1["comunidad"] = df_total_1.address.apply(direccion)

# %%
df_total_1.head()  #### ESTAMOS AQUI!!!
# Out:
#    Unnamed: 0  Unnamed: 0.1                   name  \
# 0           0             0          La Bistroteca
# 1           1             1  Los Montes de Galicia
# 2           2             2          Platea Madrid
# 3           3             3       Chow Chow Madrid
# 4           4             4           TATEL Madrid
#
#                                              address           type  \
# 0  Calle Espartinas 7, local izquierda Barrio Sal...         Fusión
# 1               Calle Azcona 46, 28028 Madrid España  Internacional
# 2     C/ Goya, 5-7 C/ Goya, 5-7, 28001 Madrid España       Italiana
# 3   Avenida de Concha Espina 55, 28016 Madrid España       Japonesa
# 4    Paseo de la Castellana, 36, 28046 Madrid España  Internacional
#
#                                    ranking     price  \
# 0     #14 de 10.414 restaurantes en Madrid  €€ - €€€
# 1      #1 de 10.414 restaurantes en Madrid  €€ - €€€
# 2    #654 de 10.414 restaurantes en Madrid  €€ - €€€
# ...

# %%
df_total_1.dtypes
# Out:
# Unnamed: 0       int64
# Unnamed: 0.1     int64
# name            object
# address         object
# type            object
# ranking         object
# price           object
# direccion       object
# comunidad       object
# dtype: object

# %%
def quitar_comas(x):
    return x.replace(',', "")

# %%
df_total_1["direccion"] = df_total_1.direccion.apply(quitar_comas)

# %%
df_total_1.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1                    name  \
# 0           0             0           La Bistroteca
# 1           1             1   Los Montes de Galicia
# 2           2             2           Platea Madrid
# 3           3             3        Chow Chow Madrid
# 4           4             4            TATEL Madrid
# 5           5             5  Chocolatería San Ginés
# 6           6             6            Kuche Madrid
# 7           7             7         Rubaiyat Madrid
# 8           8             8       Enigmatium Madrid
# 9           9             9     Ramon Freixa Madrid
#
#                                              address                  type  \
# 0  Calle Espartinas 7, local izquierda Barrio Sal...                Fusión
# 1               Calle Azcona 46, 28028 Madrid España         Internacional
# 2     C/ Goya, 5-7 C/ Goya, 5-7, 28001 Madrid España              Italiana
# 3   Avenida de Concha Espina 55, 28016 Madrid España              Japonesa
# ...

# %%
def fix_address(x):
    try:
        y = re.match('.*\d{1}', str(x))
        res = y.group()
        return res
    except:
        return x

# %%
df_total_1["street"] = df_total_1.direccion.apply(fix_address)

# %%
df_total_1
# Out:
#      Unnamed: 0  Unnamed: 0.1                       name  \
# 0             0             0              La Bistroteca
# 1             1             1      Los Montes de Galicia
# 2             2             2              Platea Madrid
# 3             3             3           Chow Chow Madrid
# 4             4             4               TATEL Madrid
# ..          ...           ...                        ...
# 496          25            25              Ganz Wine Bar
# 497          26            26                   Cafelito
# 498          27            27                Panela & Co
# 499          28            28  Sua By Triciclo In Madrid
# 500          29            29        La Máquina Original
#
#                                                address                  type  \
# 0    Calle Espartinas 7, local izquierda Barrio Sal...                Fusión
# 1                 Calle Azcona 46, 28028 Madrid España         Internacional
# ...

# %%
df_total_1["street_2"] = df_total_1["street"] + "," + df_total_1["comunidad"]

# %%
df_total_1
# Out:
#      Unnamed: 0  Unnamed: 0.1                       name  \
# 0             0             0              La Bistroteca
# 1             1             1      Los Montes de Galicia
# 2             2             2              Platea Madrid
# 3             3             3           Chow Chow Madrid
# 4             4             4               TATEL Madrid
# ..          ...           ...                        ...
# 496          25            25              Ganz Wine Bar
# 497          26            26                   Cafelito
# 498          27            27                Panela & Co
# 499          28            28  Sua By Triciclo In Madrid
# 500          29            29        La Máquina Original
#
#                                                address                  type  \
# 0    Calle Espartinas 7, local izquierda Barrio Sal...                Fusión
# 1                 Calle Azcona 46, 28028 Madrid España         Internacional
# ...

# %%
def sustituye(x):
    x = str(x).replace('C/', "Calle ")
    x = str(x).replace('c/', "Calle ")
    x = str(x).replace('C /', "Calle ")
    x = str(x).replace('c /', "Calle ")
    
    return x

# %%
df_total_1["street"] = df_total_1.street.apply(sustituye)

# %%
df_total_1["street"] = df_total_1.street.str.replace("C/ Goya 5-7 C/ Goya 5-7", "Calle Goya 5")
df_total_1["street"] = df_total_1.street.str.replace("Primer enigma a resolver Centro de Madrid",
                                                     "Calle María de Molina, 66")
df_total_1["street"] = df_total_1.street.str.replace("Calle CAVA BAJA 32", "Calle Cava Baja 32")
df_total_1["street"] = df_total_1.street.str.replace("Plaza Mayor 30 Entrada al restaurante por Calle de la Sal 2",
                                                     "Plaza Mayor 30")
df_total_1["street"] = df_total_1.street.str.replace("Plaza de San Miguel s/n", "Plaza de San Miguel")
df_total_1["street"] = df_total_1.street.str.replace("Calle Zurbano nº5", "Calle Zurbano 5")
df_total_1["street"] = df_total_1.street.str.replace("C/ LOPEZ DE ARANDA 46", "Calle Lopez de Aranda 46")

df_total_1["street"] = df_total_1.street.str.replace("Santa Maria30", "Calle Santa Maria 30")



df_total_1["street"] = df_total_1.street.str.replace("C. Mariano Barbacid 12",
                                                     "Calle Mariano Barbacid 12")

df_total_1["street"] = df_total_1.street.str.replace("Calle Santa Isabel Nº 35",
                                                     "Calle Santa Isabel 35")

df_total_1["street"] = df_total_1.street.str.replace("Calle Santa Isabel Nº 35",
                                                     "Calle Santa Isabel 35")

df_total_1["street"] = df_total_1.street.str.replace("CalleRodio 6", "Calle Rodio 6")
                                                     

df_total_1["street"] = df_total_1.street.str.replace("Calle San Martin 2 Semi-esquina con la calle Arenal 18",
                                                     "Calle San Martin 2")


df_total_1["street"] = df_total_1.street.str.replace("Calle Principe 10 Calle del Principe 10",
                                                     "Calle Principe 10")

df_total_1["street"] = df_total_1.street.str.replace("Calle del Cardenal Cisneros nr. 16","Calle del Cardenal Cisneros 16")
# Out:
# <ipython-input-27-57e47fb88a57>:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_total_1["street"] = df_total_1.street.str.replace("C. Mariano Barbacid 12",
# <ipython-input-27-57e47fb88a57>:34: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_total_1["street"] = df_total_1.street.str.replace("Calle del Cardenal Cisneros nr. 16","Calle del Cardenal Cisneros 16")

# %%
df_total_1["street"] = df_total_1.street.str.replace("Calle BORDADORES 11", "Calle Bordadores 11")

df_total_1["street"] = df_total_1.street.str.replace("Avenida Victoria s/n ", "Avenida Victoria")

df_total_1["street"] = df_total_1.street.str.replace("HUERTAS 66", "Calle Huertas 66")

df_total_1["street"] = df_total_1.street.str.replace("Calle San Pedro 22 N° 22", "Calle San Pedro 22")

df_total_1["street"] = df_total_1.street.str.replace("Plaza del humilladero esquina Cava Baja Madrid España",
                                                     "Plaza del humilladero")

df_total_1["street"] = df_total_1.street.str.replace("Plaza de la Puerta del Sol 10 5",
                                                     "Plaza de la Puerta del Sol 10")


df_total_1["street"] = df_total_1.street.str.replace("Plaza de la Puerta del Sol 10 5",
                                                     "Plaza de la Puerta del Sol 10")


df_total_1["street"] = df_total_1.street.str.replace("Calle Echegaray No 21", "Calle Echegaray 21")


df_total_1["street"] = df_total_1.street.str.replace("Calle Castello 18 Nº 18",
                                                     "Calle Castello 18")



df_total_1["street"] = df_total_1.street.str.replace("San Vicente Ferrer 51",
                                                     "Calle San Vicente Ferrer 51")

df_total_1["street"] = df_total_1.street.str.replace("Menéndez Pelayo 13", "Calle Menéndez Pelayo 13")


df_total_1["street"] = df_total_1.street.str.replace("Calle PRIM 7", "Calle Prim 7")


df_total_1["street"] = df_total_1.street.str.replace("Calle de Vallehermoso 36 Mercado de Vallehermoso Puestos 60-61-62",
                                                     "Calle de Vallehermoso 36")


df_total_1["street"] = df_total_1.street.str.replace("Calle de Vallehermoso 36 Mercado de Vallehermoso Puestos 60-61-62",
                                                     "Calle de Vallehermoso 36")


df_total_1["street"] = df_total_1.street.str.replace("Lago de la Casa de Campo s.n Lago de Casa de Campo Paseo de la Florida",
                                                     "Lago de la Casa de Campo")

df_total_1["street"] = df_total_1.street.str.replace("Calle Carretas 14 3",
                                                     "Calle Carretas 14")


df_total_1["street"] = df_total_1.street.str.replace("Calle Quero 83-85", "Calle Quero 83")


df_total_1["street"] = df_total_1.street.str.replace("Calle Serrano 61 (acceso peatonal) Paseo de la Castellana 34",
                                                     "Calle Serrano 61")

df_total_1["street"] = df_total_1.street.str.replace("Calle de Velázquez 80 Calle Velazquez 80",
                                                     "Calle de Velázquez 80")

df_total_1["street"] = df_total_1.street.str.replace("Calle Pedro Tezano 11 Villaamil 44",
                                                     "Calle Pedro Tezano 11")

df_total_1["street"] = df_total_1.street.str.replace("Constanilla de San Andres Madrid España",
                                                     "Constanilla de San Andres")


df_total_1["street"] = df_total_1.street.str.replace("Avenida Hispanidad 2-4",
                                                     "Avenida Hispanidad 2")

df_total_1["street"] = df_total_1.street.str.replace("Calle del Almte. 14 Es el número 24 no el 14",
                                                     "Calle del Almirante 14")

df_total_1["street"] = df_total_1.street.str.replace("Paseo General Martínez Campos 26, Madrid España",
                                                     "General Martínez Campos 26, Madrid España")
# Out:
# <ipython-input-77-eb316ea97725>:45: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_total_1["street"] = df_total_1.street.str.replace("Lago de la Casa de Campo s.n Lago de Casa de Campo Paseo de la Florida",
# <ipython-input-77-eb316ea97725>:55: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_total_1["street"] = df_total_1.street.str.replace("Calle Serrano 61 (acceso peatonal) Paseo de la Castellana 34",
# <ipython-input-77-eb316ea97725>:71: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_total_1["street"] = df_total_1.street.str.replace("Calle del Almte. 14 Es el número 24 no el 14",

# %%
df_total_1["street"] = df_total_1.street.str.replace("Plaza del Descubridor Diego de Ordas Santa Ingracia 120",
                                                     "Plaza del Descubridor Diego de Ordas 1")

# %%
df_total_1["street"] = df_total_1.street.str.replace("Calle Serrano 61 (acceso peatonal) Paseo de la Castellana 34",
                                                     "Calle Serrano 61")
# Out:
# <ipython-input-30-bac1641e71ac>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_total_1["street"] = df_total_1.street.str.replace("Calle Serrano 61 (acceso peatonal) Paseo de la Castellana 34",

# %%
df_total_1.street.unique()
# Out:
# array(['Calle Espartinas 7', 'Calle Azcona 46',
#        'Calle  Goya 5-7 Calle  Goya 5-7', 'Avenida de Concha Espina 55',
#        'Paseo de la Castellana 36', 'Pasadizo de San Ginés 5',
#        'Calle Princesa 18', 'Calle Juan Ramon Jimenez 37',
#        'Calle María de Molina, 66 ', 'Calle Claudio Coello 67',
#        'Paseo General Martínez Campos 26', 'Calle Cava Baja 32',
#        'Calle Reina 4', 'Calle Duque De Alba 4', 'Calle Cava Baja 35',
#        'Plaza Mayor 30', 'Calle del Molino de Viento 4', 'Calle Cádiz 4',
#        'Calle Caños del Peral 9', 'Avenida Portugal 1',
#        'Calle de Jorge Juan 10', 'Calle de la Cruz 19',
#        'Calle del Almendro 9', 'Calle Gran Via 6',
#        'Calle San Leonardo 12', 'Plaza de San Miguel ',
#        'Calle Jorge Juan 20', 'Mesón de Paños 1', 'Paseo Castellana 52',
#        'Calle Fuencarral 85', 'Calle de Recoletos 10', 'Calle Abada 2',
#        'Calle de Botoneras 6', 'Plaza Puerta de Moros 4',
# ...

# %%
df_total_1["coordinates"] = df_total_1.street.apply(get_coordenadas)

# %%
def get_coordenadas(city):
    """
    Esta función saca las coordenadas de la ciudad que le pases.
    Args: una ciudad (string).
    Return: Las coordeandas de la ciudad que le paso como argumento (latitud y longitud).
    """
    try:
        geolocator = Nominatim(user_agent="Ana")
        location = geolocator.geocode(query=city, exactly_one=True)
        #print(location)
        return location[1]
    except: 
        #print(city)
        return city

# %%
df_total_1_1 = df_total_1.sample(20)

# %%
df_total_1["coordinates"] = df_total_1.street_2.apply(get_coordenadas)

# %%
df_total_1.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                   name  \
# 0           0             0          La Bistroteca
# 1           1             1  Los Montes de Galicia
# 2           2             2          Platea Madrid
# 3           3             3       Chow Chow Madrid
# 4           4             4           TATEL Madrid
#
#                                              address           type  \
# 0  Calle Espartinas 7, local izquierda Barrio Sal...         Fusión
# 1               Calle Azcona 46, 28028 Madrid España  Internacional
# 2     C/ Goya, 5-7 C/ Goya, 5-7, 28001 Madrid España       Italiana
# 3   Avenida de Concha Espina 55, 28016 Madrid España       Japonesa
# 4    Paseo de la Castellana, 36, 28046 Madrid España  Internacional
#
#                                    ranking     price  \
# 0     #14 de 10.414 restaurantes en Madrid  €€ - €€€
# 1      #1 de 10.414 restaurantes en Madrid  €€ - €€€
# 2    #654 de 10.414 restaurantes en Madrid  €€ - €€€
# ...

# %%
df_total_1.coordinates.unique()
# Out:
# array([(40.4243394, -3.679035), (40.4326556, -3.6726411),
#        'Calle  Goya 5-7 Calle  Goya 5-7, Madrid España',
#        (40.4518842, -3.680445), (40.4324628, -3.6878077),
#        (40.4167707, -3.706803), (40.3470591, -3.831506),
#        (40.591403549999995, -3.985496800779464),
#        'Calle María de Molina, 66 , Madrid España',
#        (40.5938943, -4.1466444),
#        'Paseo General Martínez Campos 26, Madrid España',
#        'Calle Cava Baja 32, Madrid España', (40.945045, -3.6604328),
#        (40.2067694, -3.5815233), 'Calle Cava Baja 35, Madrid España',
#        (40.4157824, -3.7066073), (40.4232664, -3.7037237),
#        (40.3148903, -4.4698356), (40.4189909, -3.7085092),
#        (40.3289712, -3.8574986), (40.4237791, -3.6864786),
#        (40.4155198, -3.7017311), (40.4127139, -3.7096599),
#        (40.5443308, -3.3790235), (40.4249269, -3.7108007),
#        (40.4157141, -3.7094527), (40.5417321, -3.6258958),
# ...

# %%
get_coordenadas("General Martínez Campos 26, Madrid España")
# Out:
# (40.41780095, -3.6809532659136543)

# %%
df_total_1_1.coordinates.unique()
# Out:
# array([(40.42718735, -3.6857741915738558), (40.4206959, -3.6889616),
#        (40.4251672, -3.6989903), (40.28215425, -3.791757771626984),
#        (40.4878225, -3.353238), (40.951306, -3.7940992),
#        'Calle Santa Engracia 24, Madrid España', (40.4151538, -3.7019713),
#        (40.4339361, -3.698086), (40.5770122, -4.2081403),
#        (40.4546931, -3.6969689), (40.4232481, -3.6983566),
#        (40.3585687, -3.9032317), (40.4511232, -3.8615977),
#        'Calle General Pardiñas 61, Madrid España',
#        (40.4511875, -3.6816926), (40.4424218, -3.361057),
#        'Calle Hileras 5 y Fuentes 11, Madrid España',
#        (40.4183956, -3.7075337)], dtype=object)

# %%
get_coordenadas('Gutiérrez Solana 6, Madrid España')
# Out:
# (40.4505141, -3.6879035)

# %%
# regex : \d[28].*$    \d[28000-28999].*$
# \d{5}regex que elige 5 decimales

# %%
def delete_hashtag(x):
    x = str(x).replace('#', "")
    return x

# %%
df_total["ranking"] = df_total.ranking.apply(delete_hashtag)

# %%
def delete_string(x):
    x = str(x).replace('restaurantes en Madrid', "")
    return x

# %%
df_total["ranking"] = df_total.ranking.apply(delete_string)

# %%
def fix_address_"(x):
    y = re.match('.*\d{1}', x)
    print(y)
    return y.group(0)

# %%
y = re.match('.*\d{1}', x) #queremos quitar parte del elemento 0 de la tupla. 
print(y)

# %%
def delete_postalcode(x):
    return (re.split('\d{5}', x)[0],  #comunidad

# %%
import re
df_total_1["new_address"] = df_total_1.address.apply(delete_postalcode)

# %%
df_total_1.new_address[0]
# Out:
# 'Calle Espartinas 7 local izquierda Barrio Salamanca 28001 Madrid España'

# %%
y = df_total_1.new_address[0]

# %%
len(y)
# Out:
# 2

# %%
x = 'Paseo Castellana 89 enfrente de Torre Picasso,'

# %%
x = x.replace(',', '') # quitamos todas las comas de todos los elementos de x. 
x
# Out:
# 'Paseo Castellana 89 enfrente de Torre Picasso'

# %%
y = re.match('.*\d{1}', x) #queremos quitar parte del elemento 0 de la tupla. 
print(y)
# Out:
# <re.Match object; span=(0, 19), match='Paseo Castellana 89'>

# %%
print(y.group(0))
# Out:
# Paseo Castellana 89

# %%
#df_total

# %%
def fix_address_(x):
    return x.replace(',', "")

# %%
df_total_1["new_address"] = df_total_1.address.apply(fix_address_)

# %%
df_total_1
# Out:
#      Unnamed: 0  Unnamed: 0.1                       name  \
# 0             0             0              La Bistroteca
# 1             1             1      Los Montes de Galicia
# 2             2             2              Platea Madrid
# 3             3             3           Chow Chow Madrid
# 4             4             4               TATEL Madrid
# ..          ...           ...                        ...
# 496          25            25              Ganz Wine Bar
# 497          26            26                   Cafelito
# 498          27            27                Panela & Co
# 499          28            28  Sua By Triciclo In Madrid
# 500          29            29        La Máquina Original
#
#                                                address                  type  \
# 0    Calle Espartinas 7, local izquierda Barrio Sal...                Fusión
# 1                 Calle Azcona 46, 28028 Madrid España         Internacional
# ...

# %%
def fix_address_2(x):
    y = re.match('.*\d{1}', x)
    print(y)
    return y.group(0)

# %%
df_total_1["new_address"] = df_total_1.address.apply(fix_address_2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-512-a4826a1811d0> in <module>
# ----> 1 df_total_1["new_address"] = df_total_1.address.apply(fix_address_2)
#
# /opt/anaconda3/envs/ironhack/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /opt/anaconda3/envs/ironhack/lib/python3.8/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /opt/anaconda3/envs/ironhack/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
# ...

# %%
df_total_1["new_address"] = df_total_1.address.apply(fix_address_)
# Out:
# <re.Match object; span=(0, 59), match='Calle Espartinas 7, local izquierda Barrio Salama>
# <re.Match object; span=(0, 22), match='Calle Azcona 46, 28028'>
# <re.Match object; span=(0, 32), match='C/ Goya, 5-7 C/ Goya, 5-7, 28001'>
# <re.Match object; span=(0, 34), match='Avenida de Concha Espina 55, 28016'>
# <re.Match object; span=(0, 33), match='Paseo de la Castellana, 36, 28046'>
# <re.Match object; span=(0, 30), match='Pasadizo de San Ginés 5, 28013'>
# <re.Match object; span=(0, 24), match='Calle Princesa 18, 28015'>
# <re.Match object; span=(0, 34), match='Calle Juan Ramon Jimenez 37, 28036'>
# <re.Match object; span=(0, 48), match='Primer enigma a resolver Centro de Madrid, 28006'>
# <re.Match object; span=(0, 30), match='Calle Claudio Coello 67, 28001'>
# <re.Match object; span=(0, 40), match='Paseo General Martínez Campos, 26, 28010'>
# <re.Match object; span=(0, 30), match='Calle CAVA BAJA, 32 LOC, 28005'>
# <re.Match object; span=(0, 21), match='Calle Reina, 4, 28004'>
# ...

# %%
df_total_1
# Out:
#      Unnamed: 0  Unnamed: 0.1                       name  \
# 0             0             0              La Bistroteca
# 1             1             1      Los Montes de Galicia
# 2             2             2              Platea Madrid
# 3             3             3           Chow Chow Madrid
# 4             4             4               TATEL Madrid
# ..          ...           ...                        ...
# 496          25            25              Ganz Wine Bar
# 497          26            26                   Cafelito
# 498          27            27                Panela & Co
# 499          28            28  Sua By Triciclo In Madrid
# 500          29            29        La Máquina Original
#
#                                                address                  type  \
# 0    Calle Espartinas 7, local izquierda Barrio Sal...                Fusión
# 1                 Calle Azcona 46, 28028 Madrid España         Internacional
# ...

# %%
def fix_address(x):
    x = str(x).replace(',', "")
    print(x)
    y = re.match('.*\d{1}', x)
    return print(y.group(0))

# %%
df_total_1["new_address"] = df_total_1.address.apply(fix_address)
# Out:
# Calle Espartinas 7 local izquierda Barrio Salamanca 28001 Madrid España
# Calle Espartinas 7 local izquierda Barrio Salamanca 28001
# Calle Azcona 46 28028 Madrid España
# Calle Azcona 46 28028
# C/ Goya 5-7 C/ Goya 5-7 28001 Madrid España
# C/ Goya 5-7 C/ Goya 5-7 28001
# Avenida de Concha Espina 55 28016 Madrid España
# Avenida de Concha Espina 55 28016
# Paseo de la Castellana 36 28046 Madrid España
# Paseo de la Castellana 36 28046
# Pasadizo de San Ginés 5 28013 Madrid España
# Pasadizo de San Ginés 5 28013
# Calle Princesa 18 28015 Madrid España
# Calle Princesa 18 28015
# Calle Juan Ramon Jimenez 37 28036 Madrid España
# Calle Juan Ramon Jimenez 37 28036
# Primer enigma a resolver Centro de Madrid 28006 Madrid España
# Primer enigma a resolver Centro de Madrid 28006
# Calle Claudio Coello 67 28001 Madrid España
# Calle Claudio Coello 67 28001
# Paseo General Martínez Campos 26 28010 Madrid España
# Paseo General Martínez Campos 26 28010
# ...

# %%
df_total_1
# Out:
#      Unnamed: 0  Unnamed: 0.1                       name  \
# 0             0             0              La Bistroteca
# 1             1             1      Los Montes de Galicia
# 2             2             2              Platea Madrid
# 3             3             3           Chow Chow Madrid
# 4             4             4               TATEL Madrid
# ..          ...           ...                        ...
# 496          25            25              Ganz Wine Bar
# 497          26            26                   Cafelito
# 498          27            27                Panela & Co
# 499          28            28  Sua By Triciclo In Madrid
# 500          29            29        La Máquina Original
#
#                                                address                  type  \
# 0    Calle Espartinas 7, local izquierda Barrio Sal...                Fusión
# 1                 Calle Azcona 46, 28028 Madrid España         Internacional
# ...

# %%
df_total_1.new_address.unique()
# Out:
# array([('Calle Espartinas 7, local izquierda Barrio Salamanca, ', ' Madrid España'),
#        ('Calle Azcona 46, ', ' Madrid España'),
#        ('C/ Goya, 5-7 C/ Goya, 5-7, ', ' Madrid España'),
#        ('Avenida de Concha Espina 55, ', ' Madrid España'),
#        ('Paseo de la Castellana, 36, ', ' Madrid España'),
#        ('Pasadizo de San Ginés 5, ', ' Madrid España'),
#        ('Calle Princesa 18, ', ' Madrid España'),
#        ('Calle Juan Ramon Jimenez 37, ', ' Madrid España'),
#        ('Primer enigma a resolver Centro de Madrid, ', ' Madrid España'),
#        ('Calle Claudio Coello 67, ', ' Madrid España'),
#        ('Paseo General Martínez Campos, 26, ', ' Madrid España'),
#        ('Calle CAVA BAJA, 32 LOC, ', ' Madrid España'),
#        ('Calle Reina, 4, ', ' Madrid España'),
#        ('Calle Duque De Alba, 4, ', ' Madrid España'),
#        ('Calle Cava Baja, 35 BAJO, ', ' Madrid España'),
# ...

# %%
fix_address

# %%
print(y.group(0))
# Out:
# Plaza de la Puerta del Sol, 10 5

# %%
df_total.new_address.unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-288-7b2ae468c64a> in <module>
# ----> 1 df_total.new_address.unique()
#
# /opt/anaconda3/envs/ironhack/lib/python3.8/site-packages/pandas/core/series.py in unique(self)
#    2037         Categories (3, object): ['a' < 'b' < 'c']
#    2038         """
# -> 2039         return super().unique()
#    2040
#    2041     @overload
#
# /opt/anaconda3/envs/ironhack/lib/python3.8/site-packages/pandas/core/base.py in unique(self)
#     977                     result = np.asarray(result)
#     978         else:
# --> 979             result = unique1d(values)
#     980
#     981         return result
#
# /opt/anaconda3/envs/ironhack/lib/python3.8/site-packages/pandas/core/algorithms.py in unique(values)
#     429
#     430     table = htable(len(values))
# --> 431     uniques = table.unique(values)
# ...

# %%
def get_coordenadas(city):
    """
    Esta función saca las coordenadas de la ciudad que le pases.
    Args: una ciudad (string).
    Return: Las coordeandas de la ciudad que le paso como argumento (latitud y longitud).
    """
    geolocator = Nominatim(user_agent="Ana")
    location = geolocator.geocode(query=city, exactly_one=True)
    return location[1]

# %%
get_coordenadas(('Paseo de la Castellana, 36, ', ' Madrid España'),)
# Out:
# (40.4630575, -3.6895649)

# %%
dic = {"name": []}

driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
url = "https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=2"
driver.get(url)
driver.implicitly_wait(2)
driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
driver.implicitly_wait(10)

for i in range(1,30):
    #¿ ?
    #driver.find_element_by_css_selector(f"#BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child({1}) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title > span").click()
    #driver.implicitly_wait(20)
    #print("We're in the restaurant 💁🏼‍♀️")
    # aqui busco el nombre de cada restaurante y entro
    
    dic["name"].append(driver.find_element_by_css_selector("#BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child(1) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title").get_attribute("onclick"))
    print("We have the restaurant's name🍴")
    #aqui cojo el texto del nombre
    '''
    dic["address"] = driver.find_element_by_css_selector("#component_46 > div > div:nth-child(3) > span:nth-child(1) > span > a").text
    print("We know were it is 📍")
    #aqui cojo el texto de la dirección
    
    dic["type"] = driver.find_element_by_css_selector("#component_46 > div > div:nth-child(2) > span.dyeJW.VRlVV > a:nth-child(2)").text
    print("We know the type of food it can offer 🍕🍱🥘")
    #aqui cojo el texto de la dirección
    
    dic["ranking"] = driver.find_element_by_css_selector("#component_46 > div > div:nth-child(2) > span.dyeJW.dUpPX > a > span > b > span").text
    print("We know how good it is 📈")
    #aqui cojo el texto de la dirección
    
        
    print(dic)
      
    
# selector de restaurante (foto): 

    #BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child(1) > div > div > div > div.ui_column.is-3-desktop.is-3-tablet.is-4-mobile.thumbnail-column > div > div.frame > div > div.aspect.is-shown-at-mobile.is-hidden-tablet > div
    #BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child(2) > div > div > div > div.ui_column.is-3-desktop.is-3-tablet.is-4-mobile.thumbnail-column > div > div.frame > div > div.aspect.is-shown-at-mobile.is-hidden-tablet > div

    
#selector de restaurante (nombre):
    #BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child(1) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title > span
    #BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child(2) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title > span

# selector de direccion: 
    #component_46 > div > div:nth-child(3) > span:nth-child(1) > span > a
    
# selector de type: (varían de 46-48)
    #component_46 > div > div:nth-child(2) > span.dyeJW.VRlVV > a:nth-child(2)
    #component_46 > div > div:nth-child(2) > span.dyeJW.VRlVV > a:nth-child(2)
    #component_48 > div > div:nth-child(2) > span.dyeJW.VRlVV > a:nth-child(2)
    #component_46 > div > div:nth-child(2) > span.dyeJW.VRlVV > a:nth-child(2)
    #component_48 > div > div:nth-child(2) > span.dyeJW.VRlVV > a:nth-child(2)
    #component_46 > div > div:nth-child(2) > span.dyeJW.VRlVV > a:nth-child(2)
    
# selector de ranking: 
    #component_46 > div > div:nth-child(2) > span.dyeJW.dUpPX > a > span > b > span
    #component_48 > div > div:nth-child(2) > span.dyeJW.dUpPX > a > span > b > span
    #component_46 > div > div:nth-child(2) > span.dyeJW.dUpPX > a > span > b > span
          
# si fuese una lista -> direcciones.append(direccion)
    '''

# %%
for i in range (1,3):
    
    driver.find_element_by_css_selector(f"#BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child({i}) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title > span"). click
    # aqui busco el nombre de cada restaurante y entro
    
    diccionario["address"] = driver.find_element_by_css_selector("#component_46 > div > div:nth-child(3) > span:nth-child(1) > span > a").text
    #aqui no quiero hacer click, quiero el texto

# %%
precio = []
producto = []
descripcion = []
medidas = []
restaurant = []

driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
url = "https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=2"
driver.get(url)
driver.implicitly_wait(2)
driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
driver.implicitly_wait(10)
driver.find_element_by_css_selector("#BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child(1) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title > span").click()
driver.implicitly_wait(10)

driver.find_element_by_css_selector("#component_46 > div > div.eTnlN._W.w.O > h1").text

restaurant.append.find_element_by_css_selector("#component_46 > div > div.eTnlN._W.w.O > h1").text
print("llego a los names")

#component_46 > div > div.eTnlN._W.w.O > h1#BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child(2) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title > span



#BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child({i}) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title > span


#BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child(1) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title > span



driver.find_element_by_xpath('/html/body/itx-common/header/itx-header/div[1]/div/span').click()
driver.find_element_by_xpath('/html/body/itx-common/section/nav/div/itx-menu/div/div[2]/ul/li[6]/div/ul/li[3]/div/a').click()
driver.implicitly_wait(10)
#driver.quit()









for i in range(1,47):
    producto.append(driver.find_element_by_css_selector(f"#product-grid > article:nth-child({i}) > itx-product-item > div > div.product-info > div > h2 > a").text)
    print("llego a los names")
    precio.append(driver.find_element_by_css_selector(f"#product-grid > article:nth-child({i}) > itx-product-item > div > div.product-info > div > itx-product-price > p > span").text)
    print("llego a los precios")

#Scroll
    #load full page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    driver.implicitly_wait(10)    
    
# request the url
for i in range(1,47):
    driver.get(url)
    driver.implicitly_wait(2) # is like a time.sleep but specific of selenium
    driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
    driver.implicitly_wait(10)
    driver.find_element_by_xpath('//*[@id="ItxCategoryPage"]/body/itx-common/section/main/itx-newsletter-advice/div/div[1]/md-icon').click()

# %%
#iconos : control command barra espaciadora
