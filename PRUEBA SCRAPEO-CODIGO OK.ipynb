# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
import pandas as pd
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager

# %%
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)

opciones.headless=False    # si True, no aperece la ventana (headless=no visible)

opciones.add_argument('--start-maximized')         # comienza maximizado

opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies

#opciones.add_extension('driver_folder/adblock.crx')       # adblocker

opciones.add_argument('--incognito')              # incognito

# %%
x = list(dic.values())
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-daecf11ec6ef> in <module>
# ----> 1 x = list(dic.values())
#       2 x
#
# NameError: name 'dic' is not defined

# %%
mid_url = x[0].split(",")[3].replace("'", "").lstrip()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-da3361479ee6> in <module>
# ----> 1 mid_url = x[0].split(",")[3].replace("'", "").lstrip()
#
# NameError: name 'x' is not defined

# %%
url = 'www.tripadvisor' + mid_url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-95717792df21> in <module>
# ----> 1 url = 'www.tripadvisor' + mid_url
#
# NameError: name 'mid_url' is not defined

# %%
url

# %%
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-edc6c27c0986> in <module>
# ----> 1 driver.quit()
#
# NameError: name 'driver' is not defined

# %%
# sacar urls ESTO VALEEEEE
dic_url = {"URL": []}
lista_mid_urls = []


    
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
url = "https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=2"
driver.get(url)
driver.implicitly_wait(2)
driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
driver.implicitly_wait(10)

for i in range(1,31):
    
    try:
        dic_url["URL"].append(driver.find_element_by_css_selector(f"#BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child({i}) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title").get_attribute("onclick"))
        print("We have the restaurant's URL 🚀", i)

        urls = list(dic_url.values())
    except: 
        pass

for i in range(len(urls[0])):
    lista_mid_urls.append(urls[0][i].split(",")[3].replace("'", "").lstrip())

    # Paginas
#1  https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=3
#2  https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=4&o=30
#3  https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=5&o=60
#4  https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=6&o=90
#5  https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=7&o=120
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-6-3552a38f82d2>:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-6-3552a38f82d2>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-6-3552a38f82d2>:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dic_url["URL"].append(driver.find_element_by_css_selector(f"#BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child({i}) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title").get_attribute("onclick"))
# We have the restaurant's URL 🚀 1
# We have the restaurant's URL 🚀 2
# We have the restaurant's URL 🚀 3
# We have the restaurant's URL 🚀 4
# We have the restaurant's URL 🚀 5
# We have the restaurant's URL 🚀 7
# We have the restaurant's URL 🚀 8
# We have the restaurant's URL 🚀 9
# We have the restaurant's URL 🚀 10
# We have the restaurant's URL 🚀 11
# We have the restaurant's URL 🚀 13
# We have the restaurant's URL 🚀 14
# We have the restaurant's URL 🚀 15
# We have the restaurant's URL 🚀 16
# We have the restaurant's URL 🚀 17
# We have the restaurant's URL 🚀 19
# We have the restaurant's URL 🚀 20
# We have the restaurant's URL 🚀 21
# We have the restaurant's URL 🚀 22
# We have the restaurant's URL 🚀 23
# We have the restaurant's URL 🚀 25
# We have the restaurant's URL 🚀 26
# We have the restaurant's URL 🚀 27
# We have the restaurant's URL 🚀 28
# We have the restaurant's URL 🚀 29

# %%
lista_mid_urls
# Out:
# ['/Restaurant_Review-g187514-d9879706-Reviews-La_Bistroteca-Madrid.html',
#  '/Restaurant_Review-g187514-d2006562-Reviews-Los_Montes_de_Galicia-Madrid.html',
#  '/Restaurant_Review-g187514-d6776681-Reviews-Platea_Madrid-Madrid.html',
#  '/Restaurant_Review-g187514-d12431974-Reviews-Chow_Chow_Madrid-Madrid.html',
#  '/Restaurant_Review-g187514-d8018926-Reviews-TATEL_Madrid-Madrid.html',
#  '/Restaurant_Review-g187514-d1027419-Reviews-Chocolateria_San_Gines-Madrid.html',
#  '/Restaurant_Review-g187514-d8860328-Reviews-Kuche_Madrid-Madrid.html',
#  '/Restaurant_Review-g187514-d795430-Reviews-Rubaiyat_Madrid-Madrid.html',
#  '/Restaurant_Review-g187514-d2001274-Reviews-Enigmatium_Madrid-Madrid.html',
#  '/Restaurant_Review-g187514-d1810038-Reviews-Ramon_Freixa_Madrid-Madrid.html',
#  '/Restaurant_Review-g187514-d12276388-Reviews-Maddock_Madrid-Madrid.html',
#  '/Restaurant_Review-g187514-d988131-Reviews-Viejo_Madrid-Madrid.html',
#  '/Restaurant_Review-g187514-d10159455-Reviews-Angelita_Madrid-Madrid.html',
#  '/Restaurant_Review-g187514-d7953753-Reviews-El_Imparcial-Madrid.html',
#  '/Restaurant_Review-g187514-d697479-Reviews-Casa_Lucio-Madrid.html',
#  '/Restaurant_Review-g187514-d14117482-Reviews-Restaurante_DCorazon-Madrid.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g187514-d10382291-Reviews-Casa_Jaguar_Madrid-Madrid.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g187514-d4054722-Reviews-Cafe_del_rio_Madrid-Madrid.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g187514-d18719909-Reviews-Lobito_de_Mar_Madrid-Madrid.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g187514-d12216862-Reviews-Grama_Lounge-Madrid.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g187514-d11896546-Reviews-Astor-Madrid.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g187514-d8735932-Reviews-Oven_Mozzarella-Madrid.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g187514-d3604996-Reviews-Marisquerias_La_Chalana_Madrid_Plaza_Espana-Madrid.html']

# %%
driver.quit()

# %%
dic = {"name":[], "address":[], "type":[],"ranking":[], "price":[]}
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
for i in final_list:

    try:
        driver.get(i)
        time.sleep(5)
        driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
        dic["name"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[1]/h1").text)
        print("We have the restaurant's name🍴")
        #aqui cojo el texto del nombre)
        dic["address"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[3]/span[1]/span/a").text)
        print("We know were it is 📍")
        #aqui cojo el texto de la dirección
        dic["type"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[2]/span[3]/a[2]").text)
        print("We know the type of food it can offer 🍕🍱🥘")
        #aqui cojo el texto de la dirección
        dic["ranking"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[2]/span[2]/a/span").text)
        print("We know how good it is 📈")
        #aqui cojo el texto de la dirección
        dic["price"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[2]/span[3]/a[1]").text)
        print("How pricy is it? 💸")
        
        

        
        # /html/body/div[2]/div[1]/div/div[3]/div/div/div[4]/div/div/div
        
    except: 
        driver.get(i)
        time.sleep(5)
        dic["name"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[1]/h1").text)
        print("We have the restaurant's name🍴")
        #aqui cojo el texto del nombre)
        dic["address"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[3]/span[1]/span/a").text)
        print("We know were it is 📍")
        #aqui cojo el texto de la dirección
        dic["type"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[2]/span[3]/a[2]").text)
        print("We know the type of food it can offer 🍕🍱🥘")
        #aqui cojo el texto de la dirección
        dic["ranking"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[2]/span[2]/a/span").text)
        print("We know how good it is 📈")
        #aqui cojo el texto de la dirección
        dic["price"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[2]/span[3]/a[1]").text)
        print("How pricy is it? 💸")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/96.0.4664.45/chromedriver_mac64.zip
# Driver has been saved in cache [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45]
# <ipython-input-27-e49db2b5dfcc>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-27-e49db2b5dfcc>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
# <ipython-input-27-e49db2b5dfcc>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dic["name"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[1]/h1").text)
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# <ipython-input-27-e49db2b5dfcc>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dic["address"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[3]/span[1]/span/a").text)
# <ipython-input-27-e49db2b5dfcc>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dic["type"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[2]/span[3]/a[2]").text)
# <ipython-input-27-e49db2b5dfcc>:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dic["ranking"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[2]/span[2]/a/span").text)
# We know how good it is 📈
# How pricy is it? 💸
# <ipython-input-27-e49db2b5dfcc>:21: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dic["price"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[2]/span[3]/a[1]").text)
# <ipython-input-27-e49db2b5dfcc>:32: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dic["name"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[1]/h1").text)
# <ipython-input-27-e49db2b5dfcc>:35: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dic["address"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[3]/span[1]/span/a").text)
# <ipython-input-27-e49db2b5dfcc>:38: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dic["type"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[2]/span[3]/a[2]").text)
# <ipython-input-27-e49db2b5dfcc>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dic["ranking"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[2]/span[2]/a/span").text)
# <ipython-input-27-e49db2b5dfcc>:44: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dic["price"].append(driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/div[3]/div/div/div[2]/span[3]/a[1]").text)
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸
# We have the restaurant's name🍴
# We know were it is 📍
# We know the type of food it can offer 🍕🍱🥘
# We know how good it is 📈
# How pricy is it? 💸

# %%
print(dic)
# Out:
# {'name': ['La Bistroteca', 'La Bistroteca', 'Los Montes de Galicia', 'Platea Madrid', 'Chow Chow Madrid', 'TATEL Madrid', 'Chocolatería San Ginés', 'Kuche Madrid', 'Rubaiyat Madrid', 'Enigmatium Madrid', 'Ramon Freixa Madrid', 'Maddock Madrid', 'Restaurante El Viejo Madrid', 'Angelita Madrid', 'El Imparcial Madrid', 'Restaurante Casa Lucio', 'Restaurante DCorazon', 'Sakale', 'Rosi La Loca', 'Casa
#4 de 10.424 restaurantes en Madrid', '#72 de 10.424 restaurantes en Madrid', '#1.647 de 10.424 restaurantes en Madrid'], 'price': ['€€ - €€€', '€€ - €€€', '€€ - €€€', '€€ - €€€', '€€€€', '€€€€', '€', '€€ - €€€', '€€€€', '€€ - €€€', '€€€€', '€€ - €€€', '€€ - €€€', '€€ - €€€', '€€ - €€€', '€€ - €€€', '€€ - €€€', '€€ - €€€', '€€ - €€€', '€€ - €€€', '€€ - €€€', '€€€€', '€€ - €€€', '€€ - €€€', '€€ - €€€', '€€ - €€€']}

# %%
df = pd.DataFrame.from_dict(dic, orient='index')

# %%
df
# Out:
#                                                         0   \
# name                                         La Bistroteca
# address  Calle Espartinas 7, local izquierda Barrio Sal...
# type                                                Fusión
# ranking               #15 de 10.424 restaurantes en Madrid
# price                                             €€ - €€€
#
#                                                         1   \
# name                                         La Bistroteca
# address  Calle Espartinas 7, local izquierda Barrio Sal...
# type                                                Fusión
# ranking               #15 de 10.424 restaurantes en Madrid
# price                                             €€ - €€€
#
#                                            2   \
# name                    Los Montes de Galicia
# address  Calle Azcona 46, 28028 Madrid España
# type                            Internacional
# ranking   #1 de 10.424 restaurantes en Madrid
# price                                €€ - €€€
#
#                                                      3   \
# name                                      Platea Madrid
# address  C/ Goya, 5-7 C/ Goya, 5-7, 28001 Madrid España
# type                                           Italiana
# ranking           #653 de 10.424 restaurantes en Madrid
# price                                          €€ - €€€
#
#                                                        4   \
# name                                     Chow Chow Madrid
# address  Avenida de Concha Espina 55, 28016 Madrid España
# type                                             Japonesa
# ranking             #403 de 10.424 restaurantes en Madrid
# price                                                €€€€
#
#                                                       5   \
# name                                        TATEL Madrid
# address  Paseo de la Castellana, 36, 28046 Madrid España
# type                                       Internacional
# ranking          #1.266 de 10.424 restaurantes en Madrid
# price                                               €€€€
#
#                                                     6   \
# name                            Chocolatería San Ginés
# address   Pasadizo de San Ginés 5, 28013 Madrid España
# type                                           Postres
# ranking  N.º 18 de 477 cafeterías y teterías en Madrid
# price                                                €
#
#                                               7   \
# name                                Kuche Madrid
# address   Calle Princesa 18, 28015 Madrid España
# type                                Mediterránea
# ranking  #1.600 de 10.424 restaurantes en Madrid
# price                                   €€ - €€€
#
#                                                        8   \
# name                                      Rubaiyat Madrid
# address  Calle Juan Ramon Jimenez 37, 28036 Madrid España
# type                                 Restaurante de carne
# ranking             #877 de 10.424 restaurantes en Madrid
# price                                                €€€€
#
#                                                         9   ...  \
# name                                     Enigmatium Madrid  ...
# address  Primer enigma a resolver Centro de Madrid, 280...  ...
# type                                              Española  ...
# ranking            #1.112 de 10.424 restaurantes en Madrid  ...
# price                                             €€ - €€€  ...
#
#                                                         16  \
# name                                  Restaurante DCorazon
# address  Plaza Mayor 30 Entrada al restaurante por Call...
# type                                         Internacional
# ranking               #44 de 10.424 restaurantes en Madrid
# price                                             €€ - €€€
#
#                                                         17  \
# name                                                Sakale
# address  Calle del Molino de Viento 4, 28004 Madrid España
# type                                              Mexicana
# ranking               #41 de 10.424 restaurantes en Madrid
# price                                             €€ - €€€
#
#                                            18  \
# name                             Rosi La Loca
# address   Calle Cádiz, 4, 28012 Madrid España
# type                            Internacional
# ranking  #96 de 10.424 restaurantes en Madrid
# price                                €€ - €€€
#
#                                                     19  \
# name                                Casa Jaguar Madrid
# address  Calle Caños del Peral, 9, 28013 Madrid España
# type                                          Mexicana
# ranking          #191 de 10.424 restaurantes en Madrid
# price                                         €€ - €€€
#
#                                                         20  \
# name                                   Cafe del rio Madrid
# address  Avenida Portugal 1 Biss. Madrid Rio, 28011 Mad...
# type                                          Mediterránea
# ranking            #2.473 de 10.424 restaurantes en Madrid
# price                                             €€ - €€€
#
#                                                   21  \
# name                            Lobito de Mar Madrid
# address  Calle de Jorge Juan 10, 28001 Madrid España
# type                                    Mediterránea
# ranking      #2.459 de 10.424 restaurantes en Madrid
# price                                           €€€€
#
#                                                22  \
# name                                 Grama Lounge
# address  Calle de la Cruz 19, 28012 Madrid España
# type                                       Latina
# ranking      #23 de 10.424 restaurantes en Madrid
# price                                    €€ - €€€
#
#                                                 23  \
# name                                         Ástor
# address  Calle del Almendro 9, 28005 Madrid España
# type                                 Internacional
# ranking        #4 de 10.424 restaurantes en Madrid
# price                                     €€ - €€€
#
#                                             24  \
# name                Oven Mozzarella Gran Vía 6
# address  Calle Gran Via 6, 28013 Madrid España
# type                                  Italiana
# ranking   #72 de 10.424 restaurantes en Madrid
# price                                 €€ - €€€
#
#                                                        25
# name                               Marisquería La Chalana
# address  Calle San Leonardo, 12 bajo, 28015 Madrid España
# type                                              Marisco
# ranking           #1.647 de 10.424 restaurantes en Madrid
# price                                            €€ - €€€
#
# [5 rows x 26 columns]

# %%
df = df.transpose()
df
# Out:
#                            name  \
# 0                 La Bistroteca
# 1                 La Bistroteca
# 2         Los Montes de Galicia
# 3                 Platea Madrid
# 4              Chow Chow Madrid
# 5                  TATEL Madrid
# 6        Chocolatería San Ginés
# 7                  Kuche Madrid
# 8               Rubaiyat Madrid
# 9             Enigmatium Madrid
# 10          Ramon Freixa Madrid
# 11               Maddock Madrid
# 12  Restaurante El Viejo Madrid
# 13              Angelita Madrid
# 14          El Imparcial Madrid
# 15       Restaurante Casa Lucio
# 16         Restaurante DCorazon
# 17                       Sakale
# 18                 Rosi La Loca
# 19           Casa Jaguar Madrid
# 20          Cafe del rio Madrid
# 21         Lobito de Mar Madrid
# 22                 Grama Lounge
# 23                        Ástor
# 24   Oven Mozzarella Gran Vía 6
# 25       Marisquería La Chalana
#
#                                               address                  type  \
# 0   Calle Espartinas 7, local izquierda Barrio Sal...                Fusión
# 1   Calle Espartinas 7, local izquierda Barrio Sal...                Fusión
# 2                Calle Azcona 46, 28028 Madrid España         Internacional
# 3      C/ Goya, 5-7 C/ Goya, 5-7, 28001 Madrid España              Italiana
# 4    Avenida de Concha Espina 55, 28016 Madrid España              Japonesa
# 5     Paseo de la Castellana, 36, 28046 Madrid España         Internacional
# 6        Pasadizo de San Ginés 5, 28013 Madrid España               Postres
# 7              Calle Princesa 18, 28015 Madrid España          Mediterránea
# 8    Calle Juan Ramon Jimenez 37, 28036 Madrid España  Restaurante de carne
BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child({1}) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title > span").click()
    #driver.implicitly_wait(20)
    #print("We're in the restaurant 💁🏼‍♀️")
    # aqui busco el nombre de cada restaurante y entro
    
    dic["name"].append(driver.find_element_by_css_selector("#BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child(1) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title").get_attribute("onclick"))
    print("We have the restaurant's name🍴")
    #aqui cojo el texto del nombre
    '''
    dic["address"] = driver.find_element_by_css_selector("#component_46 > div > div:nth-child(3) > span:nth-child(1) > span > a").text
    print("We know were it is 📍")
    #aqui cojo el texto de la dirección
    
    dic["type"] = driver.find_element_by_css_selector("#component_46 > div > div:nth-child(2) > span.dyeJW.VRlVV > a:nth-child(2)").text
    print("We know the type of food it can offer 🍕🍱🥘")
    #aqui cojo el texto de la dirección
    
    dic["ranking"] = driver.find_element_by_css_selector("#component_46 > div > div:nth-child(2) > span.dyeJW.dUpPX > a > span > b > span").text
    print("We know how good it is 📈")
    #aqui cojo el texto de la dirección
    
        
    print(dic)
      
    
# selector de restaurante (foto): 

    #BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child(1) > div > div > div > div.ui_column.is-3-desktop.is-3-tablet.is-4-mobile.thumbnail-column > div > div.frame > div > div.aspect.is-shown-at-mobile.is-hidden-tablet > div
    #BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child(2) > div > div > div > div.ui_column.is-3-desktop.is-3-tablet.is-4-mobile.thumbnail-column > div > div.frame > div > div.aspect.is-shown-at-mobile.is-hidden-tablet > div

    
#selector de restaurante (nombre):
    #BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child(1) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title > span
    #BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child(2) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title > span

# selector de direccion: 
    #component_46 > div > div:nth-child(3) > span:nth-child(1) > span > a
    
# selector de type: (varían de 46-48)
    #component_46 > div > div:nth-child(2) > span.dyeJW.VRlVV > a:nth-child(2)
    #component_46 > div > div:nth-child(2) > span.dyeJW.VRlVV > a:nth-child(2)
    #component_48 > div > div:nth-child(2) > span.dyeJW.VRlVV > a:nth-child(2)
    #component_46 > div > div:nth-child(2) > span.dyeJW.VRlVV > a:nth-child(2)
    #component_48 > div > div:nth-child(2) > span.dyeJW.VRlVV > a:nth-child(2)
    #component_46 > div > div:nth-child(2) > span.dyeJW.VRlVV > a:nth-child(2)
    
# selector de ranking: 
    #component_46 > div > div:nth-child(2) > span.dyeJW.dUpPX > a > span > b > span
    #component_48 > div > div:nth-child(2) > span.dyeJW.dUpPX > a > span > b > span
    #component_46 > div > div:nth-child(2) > span.dyeJW.dUpPX > a > span > b > span
          
# si fuese una lista -> direcciones.append(direccion)
    '''
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/awalsh/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-16-0491412f0775>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# <ipython-input-16-0491412f0775> in <module>
#       1 dic = {"name": []}
#       2
# ----> 3 driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
#       4 url = "https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=2"
#       5 driver.get(url)
#
# /opt/anaconda3/envs/ironhack/lib/python3.8/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      67             service = Service(executable_path, port, service_args, service_log_path)
#      68
# ---> 69         super(WebDriver, self).__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      70                                         port, options,
#      71                                         service_args, desired_capabilities,
#
# /opt/anaconda3/envs/ironhack/lib/python3.8/site-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      91
#      92         try:
# ---> 93             RemoteWebDriver.__init__(
#      94                 self,
#      95                 command_executor=ChromiumRemoteConnection(
#
# /opt/anaconda3/envs/ironhack/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     264         self.file_detector = file_detector or LocalFileDetector()
#     265         self.start_client()
# --> 266         self.start_session(capabilities, browser_profile)
#     267
#     268     def __repr__(self):
#
# /opt/anaconda3/envs/ironhack/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in start_session(self, capabilities, browser_profile)
#     355         parameters = {"capabilities": w3c_caps,
#     356                       "desiredCapabilities": capabilities}
# --> 357         response = self.execute(Command.NEW_SESSION, parameters)
#     358         if 'sessionId' not in response:
#     359             response = response['value']
#
# /opt/anaconda3/envs/ironhack/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     416         response = self.command_executor.execute(driver_command, params)
#     417         if response:
# --> 418             self.error_handler.check_response(response)
#     419             response['value'] = self._unwrap_value(
#     420                 response.get('value', None))
#
# /opt/anaconda3/envs/ironhack/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#     244
#     245     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# InvalidArgumentException: Message: invalid argument: user data directory is already in use, please specify a unique value for --user-data-dir argument, or don't use --user-data-dir
# Stacktrace:
# 0   chromedriver                        0x00000001070f7269 __gxx_personality_v0 + 582729
# 1   chromedriver                        0x0000000107082c33 __gxx_personality_v0 + 106003
# 2   chromedriver                        0x0000000106c3fe28 chromedriver + 171560
# 3   chromedriver                        0x0000000106c62521 chromedriver + 312609
# 4   chromedriver                        0x0000000106c5e6c6 chromedriver + 296646
# 5   chromedriver                        0x0000000106c989c3 chromedriver + 534979
# 6   chromedriver                        0x0000000106c92723 chromedriver + 509731
# 7   chromedriver                        0x0000000106c6875e chromedriver + 337758
# 8   chromedriver                        0x0000000106c69a95 chromedriver + 342677
# 9   chromedriver                        0x00000001070b38ab __gxx_personality_v0 + 305803
# 10  chromedriver                        0x00000001070ca863 __gxx_personality_v0 + 399939
# 11  chromedriver                        0x00000001070cfc7f __gxx_personality_v0 + 421471
# 12  chromedriver                        0x00000001070cbbba __gxx_personality_v0 + 404890
# 13  chromedriver                        0x00000001070a7e51 __gxx_personality_v0 + 258097
# 14  chromedriver                        0x00000001070e7158 __gxx_personality_v0 + 516920
# 15  chromedriver                        0x00000001070e72e1 __gxx_personality_v0 + 517313
# 16  chromedriver                        0x00000001070fe6f8 __gxx_personality_v0 + 612568
# 17  libsystem_pthread.dylib             0x00007fff204f38fc _pthread_start + 224
# 18  libsystem_pthread.dylib             0x00007fff204ef443 thread_start + 15

# %%
for i in range (1,3):
    
    driver.find_element_by_css_selector(f"#BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child({i}) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title > span"). click
    # aqui busco el nombre de cada restaurante y entro
    
    diccionario["address"] = driver.find_element_by_css_selector("#component_46 > div > div:nth-child(3) > span:nth-child(1) > span > a").text
    #aqui no quiero hacer click, quiero el texto

# %%
precio = []
producto = []
descripcion = []
medidas = []
restaurant = []

driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
url = "https://www.tripadvisor.es/Search?q=MADRID&searchSessionId=AAC12DFCE328D1F32E893F404A794CE71638809580308ssid&sid=9F59869EAAA642E8B588911214CFAC611638809599418&blockRedirect=true&ssrc=e&geo=187514&rf=2"
driver.get(url)
driver.implicitly_wait(2)
driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
driver.implicitly_wait(10)
driver.find_element_by_css_selector("#BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child(1) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title > span").click()
driver.implicitly_wait(10)

driver.find_element_by_css_selector("#component_46 > div > div.eTnlN._W.w.O > h1").text

restaurant.append.find_element_by_css_selector("#component_46 > div > div.eTnlN._W.w.O > h1").text
print("llego a los names")

#component_46 > div > div.eTnlN._W.w.O > h1#BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child(2) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title > span



#BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child({i}) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title > span


#BODY_BLOCK_JQUERY_REFLOW > div.page > div > div.ui_container.main_wrap > div > div > div > div > div.content_column.ui_column.is-9-desktop.is-12-tablet.is-12-mobile > div > div.ui_columns.sections_wrapper > div > div.prw_rup.prw_search_search_results.ajax-content > div > div.main_content.ui_column.is-12 > div > div:nth-child(2) > div > div > div:nth-child(1) > div > div > div > div.ui_column.is-9-desktop.is-8-mobile.is-9-tablet.content-block-column > div.location-meta-block > div.result-title > span



driver.find_element_by_xpath('/html/body/itx-common/header/itx-header/div[1]/div/span').click()
driver.find_element_by_xpath('/html/body/itx-common/section/nav/div/itx-menu/div/div[2]/ul/li[6]/div/ul/li[3]/div/a').click()
driver.implicitly_wait(10)
#driver.quit()









for i in range(1,47):
    producto.append(driver.find_element_by_css_selector(f"#product-grid > article:nth-child({i}) > itx-product-item > div > div.product-info > div > h2 > a").text)
    print("llego a los names")
    precio.append(driver.find_element_by_css_selector(f"#product-grid > article:nth-child({i}) > itx-product-item > div > div.product-info > div > itx-product-price > p > span").text)
    print("llego a los precios")

#Scroll
    #load full page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    driver.implicitly_wait(10)    
    
# request the url
for i in range(1,47):
    driver.get(url)
    driver.implicitly_wait(2) # is like a time.sleep but specific of selenium
    driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
    driver.implicitly_wait(10)
    driver.find_element_by_xpath('//*[@id="ItxCategoryPage"]/body/itx-common/section/main/itx-newsletter-advice/div/div[1]/md-icon').click()

# %%
#iconos : control command barra espaciadora

# %%
<div class="result-title" onclick="widgetEvCall('handlers.openResult', event, this, '/Restaurant_Review-g187514-d9879706-Reviews-La_Bistroteca-Madrid.html', {type: 'RESTAURANTS',element: this,index: 0,section: 0,locationId: '9879706',parentId: '187514',elementType: 'title',selectedId: '9879706'});"><span>La Bistroteca</span></div>
